# %%
from pathlib import Path
import os

def load_env_file(start=None):
    start = Path(start or Path.cwd()).resolve()

    for folder in [start, *start.parents]:
        env_path = folder / ".env"

        if env_path.exists():
            print(f"Found .env at: {env_path}")

            for line in env_path.read_text().splitlines():
                line = line.strip()

                if not line or line.startswith("#") or "=" not in line:
                    continue

                key, value = line.split("=", 1)
                key = key.strip()
                value = value.strip().strip('"').strip("'")

                os.environ[key] = value

            return env_path

    print("No .env file found.")
    return None

load_env_file()

print("GITHUB_TOKEN loaded:", os.getenv("GITHUB_TOKEN") is not None)
# Out:
# Found .env at: /home/kennywong/code/ntu-sctp/repos/5m-data-2.4-data-extraction-scraping/.env
# GITHUB_TOKEN loaded: True

# %%
import os
import requests

token = os.getenv("GITHUB_TOKEN")

headers = {
    "Authorization": f"Bearer {token}",
    "Accept": "application/vnd.github+json"
}

response = requests.get(
    "https://api.github.com/rate_limit",
    headers=headers
)

print("Status code:", response.status_code)
# Out:
# Status code: 200
